# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
import os

# %% [markdown]
# ## Merging the datasets

# %%
#current work directory
path = os.getcwd()

#show the files
files = os.listdir(path)
files
# Out:
# ['.ipynb_checkpoints',
#  'audi.csv',
#  'bmw.csv',
#  'Data Cleaning.ipynb',
#  'final.csv',
#  'mercedes.csv',
#  'Web Scraping Mercedes.ipynb',
#  'Web_Scraping_Audi.ipynb',
#  'Web_Scraping_BMW.ipynb']

# %%
files_needed = ['audi.csv',
 'bmw.csv',
 'mercedes.csv']

len(files_needed)
# Out:
# 3

# %% [markdown]
# ## Creating the Dataframe

# %%
df_combined = pd.DataFrame()

for i in files_needed:
    df_combined = df_combined.append(pd.read_csv(i))
    
df_combined
# Out:
#       Unnamed: 0                                     Name      Mileage  \
# 0              0           2015 Audi A6 2.0T Premium Plus   68,672 mi.
# 1              1           2018 Audi Q7 3.0T Premium Plus   28,579 mi.
# 2              2                 2021 Audi e-tron Premium    3,818 mi.
# 3              3           2016 Audi A6 3.0T Premium Plus   52,001 mi.
# 4              4             2021 Audi RS Q8 4.0T quattro    4,169 mi.
# ...          ...                                      ...          ...
# 1195        1195   2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 1196        1196   2019 Mercedes-Benz GLC 300 Base 4MATIC   29,949 mi.
# 1197        1197          2021 Mercedes-Benz GLC 300 Base    6,236 mi.
# 1198        1198  2015 Mercedes-Benz S-Class S 550 4MATIC  109,684 mi.
# 1199        1199  2020 Mercedes-Benz A-Class A 220 4MATIC   10,228 mi.
#
#       Rating    Reviews Count                  Dealer Name     Price
# 0        4.6     (39 reviews)          Platinum Motor Cars   $24,990
# 1        3.9    (268 reviews)                Audi Brooklyn   $43,990
# 2        5.0  (1,091 reviews)                Audi Lakeland   $67,998
# 3        4.6    (584 reviews)           Toyota of Gastonia   $28,699
# 4        4.7  (1,109 reviews)              BMW of Freeport  $149,943
# ...      ...              ...                          ...       ...
# 1195     4.8  (1,548 reviews)      Koons Ford of Baltimore   $33,500
# 1196     4.8  (1,569 reviews)  Mercedes-Benz of Massapequa   $41,495
# 1197     4.6    (309 reviews)      Mercedes-Benz of Tucson   $50,551
# 1198     3.8    (532 reviews)            Merlex Auto Group   $30,966
# 1199     4.9  (1,004 reviews)               RBM of Atlanta   $39,701
#
# [3540 rows x 7 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Checking for missing values:

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3540 entries, 0 to 1199
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3540 non-null   int64
#  1   Name           3540 non-null   object
#  2   Mileage        3540 non-null   object
#  3   Rating         3540 non-null   float64
#  4   Reviews Count  3540 non-null   object
#  5   Dealer Name    3540 non-null   object
#  6   Price          3540 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 221.2+ KB

# %% [markdown]
# #### Checking for duplicate values:

# %%
df_combined.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Cleaning the Reviews Count column:

# %%
df_combined['Reviews Count'] = df_combined['Reviews Count'].apply(lambda x: x.strip('reviews)').strip('('))

df_combined
# Out:
#       Unnamed: 0                                     Name      Mileage  \
# 0              0           2015 Audi A6 2.0T Premium Plus   68,672 mi.
# 1              1           2018 Audi Q7 3.0T Premium Plus   28,579 mi.
# 2              2                 2021 Audi e-tron Premium    3,818 mi.
# 3              3           2016 Audi A6 3.0T Premium Plus   52,001 mi.
# 4              4             2021 Audi RS Q8 4.0T quattro    4,169 mi.
# ...          ...                                      ...          ...
# 1195        1195   2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 1196        1196   2019 Mercedes-Benz GLC 300 Base 4MATIC   29,949 mi.
# 1197        1197          2021 Mercedes-Benz GLC 300 Base    6,236 mi.
# 1198        1198  2015 Mercedes-Benz S-Class S 550 4MATIC  109,684 mi.
# 1199        1199  2020 Mercedes-Benz A-Class A 220 4MATIC   10,228 mi.
#
#       Rating Reviews Count                  Dealer Name     Price
# 0        4.6           39           Platinum Motor Cars   $24,990
# 1        3.9          268                 Audi Brooklyn   $43,990
# 2        5.0        1,091                 Audi Lakeland   $67,998
# 3        4.6          584            Toyota of Gastonia   $28,699
# 4        4.7        1,109               BMW of Freeport  $149,943
# ...      ...           ...                          ...       ...
# 1195     4.8        1,548       Koons Ford of Baltimore   $33,500
# 1196     4.8        1,569   Mercedes-Benz of Massapequa   $41,495
# 1197     4.6          309       Mercedes-Benz of Tucson   $50,551
# 1198     3.8          532             Merlex Auto Group   $30,966
# 1199     4.9        1,004                RBM of Atlanta   $39,701
#
# [3540 rows x 7 columns]

# %% [markdown]
# #### Cleaning the Mileage column

# %%
# Cutting the 'mi.' sign:
df_combined['Mileage'] = df_combined['Mileage'].str.strip('mi.')

df_combined
# Out:
#       Unnamed: 0                                     Name   Mileage  Rating  \
# 0              0           2015 Audi A6 2.0T Premium Plus   68,672      4.6
# 1              1           2018 Audi Q7 3.0T Premium Plus   28,579      3.9
# 2              2                 2021 Audi e-tron Premium    3,818      5.0
# 3              3           2016 Audi A6 3.0T Premium Plus   52,001      4.6
# 4              4             2021 Audi RS Q8 4.0T quattro    4,169      4.7
# ...          ...                                      ...       ...     ...
# 1195        1195   2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548      4.8
# 1196        1196   2019 Mercedes-Benz GLC 300 Base 4MATIC   29,949      4.8
# 1197        1197          2021 Mercedes-Benz GLC 300 Base    6,236      4.6
# 1198        1198  2015 Mercedes-Benz S-Class S 550 4MATIC  109,684      3.8
# 1199        1199  2020 Mercedes-Benz A-Class A 220 4MATIC   10,228      4.9
#
#      Reviews Count                  Dealer Name   Price
# 0              39           Platinum Motor Cars   24990
# 1             268                 Audi Brooklyn   43990
# 2           1,091                 Audi Lakeland   67998
# 3             584            Toyota of Gastonia   28699
# 4           1,109               BMW of Freeport  149943
# ...            ...                          ...     ...
# 1195        1,548       Koons Ford of Baltimore   33500
# 1196        1,569   Mercedes-Benz of Massapequa   41495
# 1197          309       Mercedes-Benz of Tucson   50551
# 1198          532             Merlex Auto Group   30966
# 1199        1,004                RBM of Atlanta   39701
#
# [3540 rows x 7 columns]

# %% [markdown]
# #### Cleaning the price column

# %%
# Cutting the '$' sign:
df_combined['Price'] = df_combined['Price'].str.strip('$')

df_combined
# Out:
#       Unnamed: 0                                     Name      Mileage  \
# 0              0           2015 Audi A6 2.0T Premium Plus   68,672 mi.
# 1              1           2018 Audi Q7 3.0T Premium Plus   28,579 mi.
# 2              2                 2021 Audi e-tron Premium    3,818 mi.
# 3              3           2016 Audi A6 3.0T Premium Plus   52,001 mi.
# 4              4             2021 Audi RS Q8 4.0T quattro    4,169 mi.
# ...          ...                                      ...          ...
# 1195        1195   2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 1196        1196   2019 Mercedes-Benz GLC 300 Base 4MATIC   29,949 mi.
# 1197        1197          2021 Mercedes-Benz GLC 300 Base    6,236 mi.
# 1198        1198  2015 Mercedes-Benz S-Class S 550 4MATIC  109,684 mi.
# 1199        1199  2020 Mercedes-Benz A-Class A 220 4MATIC   10,228 mi.
#
#       Rating Reviews Count                  Dealer Name    Price
# 0        4.6           39           Platinum Motor Cars   24,990
# 1        3.9          268                 Audi Brooklyn   43,990
# 2        5.0        1,091                 Audi Lakeland   67,998
# 3        4.6          584            Toyota of Gastonia   28,699
# 4        4.7        1,109               BMW of Freeport  149,943
# ...      ...           ...                          ...      ...
# 1195     4.8        1,548       Koons Ford of Baltimore   33,500
# 1196     4.8        1,569   Mercedes-Benz of Massapequa   41,495
# 1197     4.6          309       Mercedes-Benz of Tucson   50,551
# 1198     3.8          532             Merlex Auto Group   30,966
# 1199     4.9        1,004                RBM of Atlanta   39,701
#
# [3540 rows x 7 columns]

# %%
# Cutting the ',' in price:
df_combined['Price'] = df_combined['Price'].str.replace(',', '')

df_combined
# Out:
#       Unnamed: 0                                     Name      Mileage  \
# 0              0           2015 Audi A6 2.0T Premium Plus   68,672 mi.
# 1              1           2018 Audi Q7 3.0T Premium Plus   28,579 mi.
# 2              2                 2021 Audi e-tron Premium    3,818 mi.
# 3              3           2016 Audi A6 3.0T Premium Plus   52,001 mi.
# 4              4             2021 Audi RS Q8 4.0T quattro    4,169 mi.
# ...          ...                                      ...          ...
# 1195        1195   2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 1196        1196   2019 Mercedes-Benz GLC 300 Base 4MATIC   29,949 mi.
# 1197        1197          2021 Mercedes-Benz GLC 300 Base    6,236 mi.
# 1198        1198  2015 Mercedes-Benz S-Class S 550 4MATIC  109,684 mi.
# 1199        1199  2020 Mercedes-Benz A-Class A 220 4MATIC   10,228 mi.
#
#       Rating Reviews Count                  Dealer Name   Price
# 0        4.6           39           Platinum Motor Cars   24990
# 1        3.9          268                 Audi Brooklyn   43990
# 2        5.0        1,091                 Audi Lakeland   67998
# 3        4.6          584            Toyota of Gastonia   28699
# 4        4.7        1,109               BMW of Freeport  149943
# ...      ...           ...                          ...     ...
# 1195     4.8        1,548       Koons Ford of Baltimore   33500
# 1196     4.8        1,569   Mercedes-Benz of Massapequa   41495
# 1197     4.6          309       Mercedes-Benz of Tucson   50551
# 1198     3.8          532             Merlex Auto Group   30966
# 1199     4.9        1,004                RBM of Atlanta   39701
#
# [3540 rows x 7 columns]

# %% [markdown]
# #### Converting the price column to integer

# %%
#checking if the price column is numeric
is_numeric_dtype(df_combined['Price'])
# Out:
# False

# %%
#changing the data type of the column to int
df_combined['Price'] = df_combined['Price'].astype(int)

# %% [markdown]
# #### Converting the Mileage column to integer

# %%
#checking if the Mileage column is numeric
is_numeric_dtype(df_combined['Mileage'])
# Out:
# False

# %%
#changing the data type of the column to int
df_combined['Mileage'] = df_combined['Mileage'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-dcc49be4ca08> in <module>
#       1 #changing the data type of the column to int
# ----> 2 df_combined['Mileage'] = df_combined['Mileage'].astype(int)
#
# ~\anaconda3\envs\webscrape\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\envs\webscrape\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\anaconda3\envs\webscrape\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\anaconda3\envs\webscrape\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\envs\webscrape\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '68,672 '

# %%
#replacing the ','
df_combined['Mileage'] = df_combined['Mileage'].apply(lambda x: x.replace(',', '') if ',' in x else x)

# %%
df_combined
# Out:
#       Unnamed: 0                                     Name  Mileage  Rating  \
# 0              0           2015 Audi A6 2.0T Premium Plus   68672      4.6
# 1              1           2018 Audi Q7 3.0T Premium Plus   28579      3.9
# 2              2                 2021 Audi e-tron Premium    3818      5.0
# 3              3           2016 Audi A6 3.0T Premium Plus   52001      4.6
# 4              4             2021 Audi RS Q8 4.0T quattro    4169      4.7
# ...          ...                                      ...      ...     ...
# 1195        1195   2017 Mercedes-Benz GLE 350 Base 4MATIC   49548      4.8
# 1196        1196   2019 Mercedes-Benz GLC 300 Base 4MATIC   29949      4.8
# 1197        1197          2021 Mercedes-Benz GLC 300 Base    6236      4.6
# 1198        1198  2015 Mercedes-Benz S-Class S 550 4MATIC  109684      3.8
# 1199        1199  2020 Mercedes-Benz A-Class A 220 4MATIC   10228      4.9
#
#      Reviews Count                  Dealer Name   Price
# 0              39           Platinum Motor Cars   24990
# 1             268                 Audi Brooklyn   43990
# 2           1,091                 Audi Lakeland   67998
# 3             584            Toyota of Gastonia   28699
# 4           1,109               BMW of Freeport  149943
# ...            ...                          ...     ...
# 1195        1,548       Koons Ford of Baltimore   33500
# 1196        1,569   Mercedes-Benz of Massapequa   41495
# 1197          309       Mercedes-Benz of Tucson   50551
# 1198          532             Merlex Auto Group   30966
# 1199        1,004                RBM of Atlanta   39701
#
# [3540 rows x 7 columns]

# %% [markdown]
# ## Saving the Final Dataframe

# %%
df_combined.to_csv('final.csv')
